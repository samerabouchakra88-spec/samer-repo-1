# %% [markdown]
# <a href="https://colab.research.google.com/github/samerabouchakra88-spec/samer-repo-1/blob/main/Final_Project__oil__EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
olive_oil_df = pd.read_csv("/content/ammatourolives_final.csv")

# %%
olive_oil_df.head()
# Out:
#    Year            Field_ID  Altitude_m  Annual_Rainfall_mm_year  \
# 0  2015  Ammatour_1_Field_1       738.0                   1074.1
# 1  2016  Ammatour_1_Field_1       738.0                   1186.8
# 2  2017  Ammatour_1_Field_1       738.0                   1032.5
# 3  2018  Ammatour_1_Field_1       738.0                   1148.2
# 4  2019  Ammatour_1_Field_1       738.0                   1099.8
#
#    Spring_Rainfall_mm_season  Summer_Max_Temp_C_avg  Frost_Days_count  \
# 0                      230.0                   32.4             31.75
# 1                      242.6                   31.7             35.75
# 2                      236.6                   33.1             28.75
# 3                      225.5                   32.0             33.75
# 4                      216.1                   32.7             30.75
#
#    Irrigation_L_per_tree  Tree_Age_Years  Tree_Density_per_hectare  \
# 0                  299.9              53                       203
# ...

# %%
olive_oil_df.describe()
# Out:
#               Year  Altitude_m  Annual_Rainfall_mm_year  \
# count   200.000000  200.000000               200.000000
# mean   2019.500000  699.765000              1050.106000
# std       2.879489   53.712582                97.214634
# min    2015.000000  600.000000               810.100000
# 25%    2017.000000  672.450000               979.375000
# 50%    2019.500000  696.200000              1058.550000
# 75%    2022.000000  738.650000              1116.925000
# max    2024.000000  800.000000              1297.000000
#
#        Spring_Rainfall_mm_season  Summer_Max_Temp_C_avg  Frost_Days_count  \
# count                 200.000000             200.000000        200.000000
# mean                  220.400500              32.340500         26.882000
# std                    24.136341               0.949589          7.835649
# min                   167.900000              25.900000          8.400000
# 25%                   201.500000              31.900000         21.250000
# ...

# %%
olive_oil_df.Irrigation_L_per_tree.unique()
# Out:
# array([ 299.9,  137. ,  458.4,  202.1,  445. ,  189.5,  275.9,  955.4,
#         326.8,  640.3,  936.3,  694.6,  892.9,  775.1,  405.3,  243.9,
#         864.6,  520.6,  585.8,  298.2,  282.6, 1219. ,  318.5, 1536.1,
#         554.9, 1294.3,  355.6, 1428.9,  877.2,  988.8,  454.8,  254.4,
#         514. ,  758.1,  185.8,  630.5,  897.1,  505. ,  489.5,  654.8,
#         333.5,    0. ,  810.3,  760.3,  796.3,  383.6,  723. ,  750.4,
#         739.5,  297.8,  534.6,  434.4, 1524.6, 1555.5,  756.8, 1284.6,
#         384. , 1637.9,  719.6,  818.8,  693.9, 1410.4,  436.6,  640.2,
#        1304.4,  521.3,  978.1,  616.6])

# %%
olive_oil_df.Soil_Type.unique()
# Out:
# array(['Clay', 'Loam', 'Sandy_Loam'], dtype=object)

# %%
import seaborn as sns

# %%
sns.violinplot(x='Olives_Produced_kg_per_hectare', y='Soil_Type', data=olive_oil_df)
# Out:
# <Axes: xlabel='Olives_Produced_kg_per_hectare', ylabel='Soil_Type'>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
plt.figure(figsize=(10,5))
sns.heatmap(olive_oil_df.select_dtypes(include=np.number).corr(),annot=True,vmin=0,vmax=1,cmap='viridis')
# Out:
# <Axes: >

# %%
olive_oil_df.plot(kind='scatter', x='Irrigation_L_per_tree', y='Altitude_m')
# Out:
# <Axes: xlabel='Irrigation_L_per_tree', ylabel='Altitude_m'>

# %%
olive_oil_df.plot(kind='scatter', x='Irrigation_L_per_tree', y='Oil_Yield_kg_per_hectare')
# Out:
# <Axes: xlabel='Irrigation_L_per_tree', ylabel='Oil_Yield_kg_per_hectare'>

# %%
plt.figure(figsize=(18, 18))
numeric_cols = olive_oil_df.select_dtypes(include=np.number).columns

for i, col in enumerate(numeric_cols):
    plt.subplot(5, 3, i+1) # each row three figure
    x = olive_oil_df[col] #x-axis
    y = olive_oil_df['Irrigation_L_per_tree'] #y-axis
    plt.plot(x, y, 'o')
    # Create regression line
    plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1)) (np.unique(x)),
    color='red')
    plt.xlabel(col) # x-label
    plt.ylabel('Irrigation_L_per_tree') # y-label

# %%
plt.figure(figsize=(18, 18))
numeric_cols = olive_oil_df.select_dtypes(include=np.number).columns

for i, col in enumerate(numeric_cols):
    plt.subplot(5, 3, i+1) # each row three figure
    x = olive_oil_df[col] #x-axis
    y = olive_oil_df['Altitude_m'] #y-axis
    plt.plot(x, y, 'o')
    # Create regression line
    plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1)) (np.unique(x)),
    color='red')
    plt.xlabel(col) # x-label
    plt.ylabel('Altitude_m') # y-label

# %%
plt.figure(figsize=(18, 18))
numeric_cols = olive_oil_df.select_dtypes(include=np.number).columns

for i, col in enumerate(numeric_cols):
    plt.subplot(5, 3, i+1)
    x = olive_oil_df[col]
    y = olive_oil_df['Soil_Type']
    plt.plot(x, y, 'o')

    plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1)) (np.unique(x)),
    color='red')
    plt.xlabel(col)
    plt.ylabel('Soil_Type')

# %%
olive_oil_df['Olives_Produced_kg_per_hectare_quantile_bins'] = pd.qcut(olive_oil_df['Olives_Produced_kg_per_hectare'], 10)
soil_type_counts = olive_oil_df.groupby('Olives_Produced_kg_per_hectare_quantile_bins')['Soil_Type'].value_counts().unstack(fill_value=0)
soil_type_counts.plot.bar(figsize=(12, 6))
plt.title('Distribution of Soil_Type across Olives_Produced_kg_per_hectare Quantiles')
plt.xlabel('Olives_Produced_kg_per_hectare Quantile Bins')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(18, 18))
numeric_cols = olive_oil_df.select_dtypes(include=np.number).columns

for i, col in enumerate(numeric_cols):
    plt.subplot(5, 3, i+1)
    x = olive_oil_df[col]
    y = olive_oil_df['Pest_Pressure_Index']
    plt.plot(x, y, 'o')

    plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1)) (np.unique(x)),
    color='red')
    plt.xlabel(col)
    plt.ylabel('Pest_Pressure_Index')
